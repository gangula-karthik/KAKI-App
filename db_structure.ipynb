# %% [markdown]
# # Homepage

# %%
# social media post table

# {
#   "posts": {
#     "postId1": {
#       "post_id": "postId1",
#       "user_id": "userId1",
#       "content": "This is my first post!",
#       "image_url": "https://firebasestorage.com",
#       "created_at": "2023-07-23T15:30:00Z",
#       "upvote": 10,
#       "downvote": 2,
#             "bookmarks": {
#                   "userId2": true,
#                   "userId3": true
#             },
#             "flags": {
#                   "userId4": true
#             },
#       "comments": {
#         "commentId1": {
#           "user_id": "userId2",
#           "content": "Nice post!",
#           "created_at": "2023-07-23T15:35:00Z"
#         },
#         "commentId2": {
#           "user_id": "userId3",
#           "content": "I agree!",
#           "created_at": "2023-07-23T15:40:00Z"
#         }
#       }
#     },
#     "postId2": {
#       "post_id": "postId2",
#       "user_id": "userId2",
#       "content": "Check out this cool photo!",
#       "image_url": "https://firebasestorage.com",
#       "created_at": "2023-07-23T15:35:00Z",
#       "upvote": 10,
#       "downvote": 2,
#             "bookmarks": {
#                   "userId2": true,
#                   "userId3": true
#             },
#             "flags": {
#                   "userId4": true
#             },
#       "comments": {
#         "commentId3": {
#           "user_id": "userId1",
#           "content": "Great photo!",
#           "created_at": "2023-07-23T15:45:00Z"
#         }
#       }
#     }
#   }
# }

# %%
# friend request table


# {
#   "friendRequests": {
#     "requestId1": {
#       "from_user_id": "userId1",
#       "to_user_id": "userId2",
#       "status": "pending",
#       "sent_at": "2023-07-23T15:30:00Z",
#       "action_at": "2023-07-23T15:40:00Z"
#     },
#     "requestId2": {
#       "from_user_id": "userId3",
#       "to_user_id": "userId1",
#       "status": "accepted",
#       "sent_at": "2023-07-23T15:35:00Z",
#       "action_at": "2023-07-23T15:40:00Z"
#     },
#     "requestId3": {
#       "from_user_id": "userId2",
#       "to_user_id": "userId3",
#       "status": "rejected",
#       "sent_at": "2023-07-23T15:35:00Z",
#       "action_at": "2023-07-23T15:40:00Z"
#     }
#   }
# }

# %%
# notice board table
# types: Notice, Ads, Events 

# {
#   "noticeBoard": {
#     "noticeId1": {
#       "notice_id": "noticeId1",
#       "title": "Notice 1",
#       "content": "This is notice 1",
#       "created_at": "2023-07-23T15:30:00Z",
#       "updated_at": "2023-07-23T15:30:00Z"
#       "image_url": "https://firebasestorage.com",
#       "details_link": "https://google.com",
#       "type": "Notice"
#     },
#     "noticeId1": {
#       "notice_id": "noticeId1",
#       "title": "Notice 1",
#       "content": "This is notice 1",
#       "created_at": "2023-07-23T15:30:00Z",
#       "updated_at": "2023-07-23T15:30:00Z"
#       "image_url": "https://firebasestorage.com",
#       "details_link": "https://google.com",
#       "type": "Ads"
#     },
# }

# %%
# chat table 

# {
#   "conversations": {
#     "conversationId1": {
#       "user1_id": "userId1",
#       "user2_id": "userId2",
#       "created_at": "2023-07-23T15:30:00Z",
#       "messages": {
#         "messageId1": {
#           "from_user_id": "userId1",
#           "content": "Hello!",
#           "sent_at": "2023-07-23T15:30:00Z"
#         },
#         "messageId2": {
#           "from_user_id": "userId2",
#           "content": "Hi there!",
#           "sent_at": "2023-07-23T15:31:00Z"
#         }
#       }
#     },
#     "conversationId2": {
#       "user1_id": "userId2",
#       "user2_id": "userId3",
#       "created_at": "2023-07-23T15:35:00Z",
#       "messages": {
#         "messageId3": {
#           "from_user_id": "userId2",
#           "content": "Hey!",
#           "sent_at": "2023-07-23T15:35:00Z"
#         },
#         "messageId4": {
#           "from_user_id": "userId3",
#           "content": "Hello there!",
#           "sent_at": "2023-07-23T15:36:00Z"
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# # Customer Support

# %%
# tickets table

# {
#   "tickets": {
#     "ticketId1": {
#       "ticket_id": "ticketId1",
#       "user_id": "userId1",
#       "staff_id": "staffId1",
#       "subject": "Subject text",
#       "topic": "Topic text",
#       "status": "Open",
#       "subject_sentiment": "Positive",
#       "ml_priority": "High",
#       "descriptions": "Description 1",
#       "opened_at": "2023-07-23T15:30:00Z",
#       "closed_at": null
#     },
#     "ticketId2": {
#       "ticket_id": "ticketId2",
#       "user_id": "userId2",
#       "staff_id": "staffId2",
#       "subject": "Another subject text",
#       "topic": "Another topic text",
#       "status": "Closed",
#       "subject_sentiment": "Negative",
#       "ml_priority": "Low",
#       "descriptions": "Description 2",
#       "opened_at": "2023-07-20T15:30:00Z",
#       "closed_at": "2023-07-23T15:30:00Z"
#     }
#   }
# }

# %%
# chat with staff table

# {
#   "chats": {
#     "chatId1": {
#       "user_id": "userId1",
#       "staff_id": "staffId1",
#       "ticket_id": "ticketId1",
#       "messages": {
#         "messageId1": {
#           "sent_by": "userId1",
#           "timestamp": "2023-07-23T15:30:00Z",
#           "content": "Hello, I have an issue with my account."
#         },
#         "messageId2": {
#           "sent_by": "staffId1",
#           "timestamp": "2023-07-23T15:31:00Z",
#           "content": "Sure, I'll be happy to help. Can you please explain the issue?"
#         }
#       }
#     }
#   }
# }

# %%
# FAQ table

# {
#   "faqs": {
#     "faqId1": {
#       "question": "What is the refund policy?",
#       "answer": "Our refund policy is ...",
#       "last_updated_at": "2023-07-24T15:30:00Z",
#       "related_topics": "www.ticket1.com"
#     },
#     "faqId2": {
#       "question": "How to reset my password?",
#       "answer": "You can reset your password by ...",
#       "last_updated_at": "2023-07-25T15:35:00Z",
#       "related_topics": "www.ticket1.com"
#     }
#   }
# }
